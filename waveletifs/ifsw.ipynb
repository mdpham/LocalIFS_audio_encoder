# %%
using Wavelets
using PyPlot
using WAV

# %%
J = 12
n = 2^J
x = testfunction(n,"Bumps")
y = dwt(x, wavelet(WT.db2))
d,l = wplotdots(y, 0.1, n)
A = wplotim(y)

fig, ax = plt[:subplots](3, 1, sharex=true)
ax[1][:plot](x, "k")
ax[1][:set_xlim]([0,n])
ax[1][:set_ylabel](L"signal $x$")
ax[2][:scatter](d,l)
ax[2][:margins](0.05)
ax[2][:set_ylim](ax[2][:get_ylim]()[2:-1:1])
ax[2][:set_ylabel](L"level $j$")
ax[3][:imshow](A,aspect="auto",interpolation="none")
ax[3][:set_ylim]([J-0.5,-0.5])
ax[3][:set_ylabel](L"level $j$")

fig[:set_size_inches](6,5)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x35a293450>)

# %%
y, fs = wavread("violin.wav")
J = 15
y = +(y[1:32768,1],y[1:32768,2])/2
n = length(y)
w = dwt(y, wavelet(WT.db2), 2)
d,l = wplotdots(w, 0.1, n)
A = wplotim(w)

fig, ax = plt[:subplots](3, 1, sharex=true)
ax[1][:plot](y, "k")
ax[1][:set_xlim]([0,n])
ax[1][:set_ylabel](L"signal $x$")
ax[2][:scatter](d,l)
ax[2][:margins](0.05)
ax[2][:set_ylim](ax[2][:get_ylim]()[2:-1:1])
ax[2][:set_ylabel](L"level $j$")
ax[3][:imshow](A,aspect="auto",interpolation="none")
ax[3][:set_ylim]([J-0.5,-0.5])
ax[3][:set_ylabel](L"level $j$")

# fig[:set_size_inches](6,5)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x332678050>)
# PyObject <matplotlib.text.Text object at 0x326b3d1d0>

# %%
l
# Out:
# 4185-element Array{Int64,1}:
#  10
#  10
#  10
#  10
#  10
#  10
#  10
#  10
#  10
#  10
#  10
#  10
#  10
#   ⋮
#  12
#  12
#  12
#  13
#  13
#  13
#  13
#  13
#  13
#  13
#  13
#  13
